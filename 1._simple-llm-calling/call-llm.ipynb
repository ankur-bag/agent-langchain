# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_groq import ChatGroq

load_dotenv()
# Out:
# True

# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()

llm = ChatGoogleGenerativeAI(model="gemma-4-31b-it")

response = llm.invoke("What is Agentic AI?")

print(response.text)
# Out:
# **Agentic AI** refers to artificial intelligence systems that do not just process information or generate text, but can **independently take action** to achieve a specific goal.
#
# While traditional Generative AI (like a standard chatbot) is **passive**—it waits for a prompt and provides a response—Agentic AI is **active**. It can reason, plan, use tools, and iterate on its own work without needing a human to guide every single step.
#
# Here is a detailed breakdown of what makes AI "agentic," how it differs from standard AI, and how it works.
#
# ---
#
# ### 1. The Core Difference: Passive vs. Agentic
#
# To understand Agentic AI, it helps to compare it to the Generative AI most people are familiar with:
#
# | Feature | Generative AI (Passive) | Agentic AI (Active) |
# | :--- | :--- | :--- |
# | **Role** | A knowledgeable consultant. | A capable employee/assistant. |
# | **Interaction** | Prompt $\rightarrow$ Response. | Goal $\rightarrow$ Execution $\rightarrow$ Result. |
# ...

# %%
response = llm.invoke([
    ["system" , "you are a helpful assistant that answers in short one line"],
    ["human", "how many moons does jupiter have?"]
])
print(response.text)
# Out:
# Jupiter has 95 moons.

# %%
prompt = "write a single tagline for a quirky coffee shop. only out put the tagline, nothing else"

llm = ChatGoogleGenerativeAI(model = "gemini-2.5-flash", temperature=0)

response = llm.invoke(prompt)
print(response.text)
# Out:
# Coffee, delightfully askew.

# %%
prompt = "write a single tagline for a quirky coffee shop. only out put the tagline, nothing else"

llm = ChatGoogleGenerativeAI(model = "gemini-2.5-flash", temperature=1)

response = llm.invoke(prompt)
print(response.text)
# Out:
# Sip the Strange.

# %%
llm = ChatGroq(model="qwen/qwen3-32b", reasoning_format= "parsed")
messages = [
    (
        "system",
        "You are a helpful asstant that gives a short asnwer to a question"
        
        ),
    
    (
        "human",
        "how many moons does jupiter have?"
    )
]

response = llm.invoke(messages)
print(response.text)
# Out:
# As of the latest data in 2023, Jupiter has **95 confirmed moons**. This number may increase as new discoveries are made.
